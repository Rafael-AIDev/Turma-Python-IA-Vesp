# %% [markdown]
# # Título nível 1
# ## Título nível 2
# ### Título nível 3
# ---

# %% [markdown]
# *Itálico*<br />
# **Negrito**<br />
# ***Negrito itálico***<br />

# %% [markdown]
# Este é um texto normal!
# Exemplo de um código *hello world* no *markdown*:<br />
# `print("Hello World")`.
# <br />
# <br />
# 1. Você vai clicar em **Não**?<br /><br />
# <input type = "radio" name="questao"><span>Sim</span><br />
# <input type = "radio" name="questao"><span>Não</span><br />
# <br />
# 2. Informe suas habilidades:
# <br />
# <input type = "checkbox" name="hab" /> HTML<br />
# <input type = "checkbox" name="hab" /> Java<br />
# <input type = "checkbox" name="hab" /> Python<br />

# %% [markdown]
# ### Tópicos:
#
# - Tópico 1
# - Tópico 2
# - Tópico 3
#
# ### Númeração:
#
# 1. Numeração 1
# 2. Numeração 2
# 3. Numeração 3

# %% [markdown]
# # Traballhando com códigos em Jupyter:
# ---
# Abaixo segue um exmplo de um código funcional em Python rodando em um notebook:

# %%
n1 = 15
n2 = 5
n3 = n1 + n2
print(f'Qual o nome do filme?\nResposta = O Código dá {n3}')
# Out:
# Qual o nome do filme?
# Resposta = O Código dá 20

# %% [markdown]
# Repare que o código das cúlulas consideram o resultado das células anteriores do mesmo notebook. Observe no código a seguir:

# %%
x = 10

print(f'Resultado = {x*n3}')
# Out:
# Resultado = 200

# %% [markdown]
# Vamos ver como um código de entrada de dados se comporta em um notebook:

# %%
texto = input('Informe um texto a ser exibido na célula: ')
print(texto)
# Out:
# Este é um exemplo de texto no notebook

# %% [markdown]
# ![Sem título.png](<attachment:Sem título.png>)
# <br />
# ![1d7b14c4407fcdea5faadd6539a7cd9d.jpeg](attachment:1d7b14c4407fcdea5faadd6539a7cd9d.jpeg)
# <br />
# <br />
# Exemplo de imagem no markdown
# <br />
